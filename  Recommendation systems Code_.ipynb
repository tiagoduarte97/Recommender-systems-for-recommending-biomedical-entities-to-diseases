# %% [markdown]
# Random Split 80/20

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import train_test_split, GridSearchCV
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score

# Load dataset
data = pd.read_csv('all_articles_files_names_merge_final7.csv', sep=',')

# Define the reader
reader = Reader(rating_scale=(0, 100))

# Convert the DataFrame to the format expected by Surprise
dataset = Dataset.load_from_df(data[['id', 'gene', 'article_count']], reader=reader)

# Random split 80/20
trainset, testset = train_test_split(dataset, test_size=0.2)

# Define the parameter space for GridSearch
param_grid = {'k': [10, 20, 30]}

# Perform the grid search
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(dataset)

# Access the best found parameters
best_params = grid_search.best_params['rmse']

# Train the model with the training set using the best parameters
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Make predictions on the test set
predictions = model.test(testset)

# Calculate evaluation metrics
accuracy.rmse(predictions)
accuracy.mae(predictions)

# Retrieve predicted and actual ratings
predicted_ratings = [pred.est for pred in predictions]
true_ratings = [pred.r_ui for pred in predictions]

# Convert ratings to binary labels based on the threshold
threshold = 3.5
predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

# Calculate precision, recall, and F1-score metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Target author for recommendation
author_id = 4817

# Retrieve all genes mentioned by the target author
genes_target_author = data[data['id'] == author_id]['gene'].unique()

# Make predictions for genes not mentioned by the target author.
genes_not_mentioned = data[~data['gene'].isin(genes_target_author)]['gene'].unique()

predictions = []

for gene in genes_not_mentioned:
    prediction = model.predict(author_id, gene)
    predictions.append((author_id, gene, prediction.est))

# Sort the predictions in descending order
sorted_predictions = sorted(predictions, key=lambda x: x[2], reverse=True)

# Retrieve the author's name
author_name = data[data['id'] == author_id]['author/disease'].iloc[0]

# Calculate scores based on the recommendation position
# The higher the position, the lower the score
total_recommendations = len(sorted_predictions)
scores = [(total_recommendations - i) / total_recommendations * 100 for i in range(total_recommendations)]

# Display normalized scores
for i, (author, gene, _) in enumerate(sorted_predictions):
    print(f'Recommendation {i+1}: Author ID: {author}, Author Name: {author_name}, Gene: {gene}, Score: {scores[i]:.2f}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.2724
# MAE:  0.3744
# Precision: 0.8569636135508155
# Recall: 1.0
# F1 Score: 0.922972972972973
# Recommendation 1: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: oxytocin receptor, Score: 100.00
# Recommendation 2: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: catalase, Score: 99.62
# Recommendation 3: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ceruloplasmin, Score: 99.25
# Recommendation 4: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurexophilin 1, Score: 98.87
# Recommendation 5: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: islet cell autoantigen 1, Score: 98.49
# Recommendation 6: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: homeobox A1, Score: 98.11
# Recommendation 7: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: statherin, Score: 97.74
# Recommendation 8: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histatin 1, Score: 97.36
# Recommendation 9: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 3, Score: 96.98
# Recommendation 10: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: arginine vasopressin, Score: 96.60
# Recommendation 11: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: translocator protein, Score: 96.23
# Recommendation 12: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: parvalbumin, Score: 95.85
# Recommendation 13: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prolactin, Score: 95.47
# Recommendation 14: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: leptin, Score: 95.09
# Recommendation 15: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lactase, Score: 94.72
# Recommendation 16: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: androgen receptor, Score: 94.34
# Recommendation 17: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TBC1 domain family member 7, Score: 93.96
# Recommendation 18: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatase and tensin homolog, Score: 93.58
# Recommendation 19: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: C-reactive protein, Score: 93.21
# Recommendation 20: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nerve growth factor, Score: 92.83
# Recommendation 21: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: gastrin, Score: 92.45
# Recommendation 22: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: epidermal growth factor, Score: 92.08
# Recommendation 23: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: resistin, Score: 91.70
# Recommendation 24: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apelin, Score: 91.32
# Recommendation 25: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: albumin, Score: 90.94
# Recommendation 26: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: biotinidase, Score: 90.57
# Recommendation 27: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: SH3 and multiple ankyrin repeat domains 3, Score: 90.19
# Recommendation 28: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: synaptophysin, Score: 89.81
# Recommendation 29: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenosine deaminase, Score: 89.43
# Recommendation 30: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenylosuccinate lyase, Score: 89.06
# Recommendation 31: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ribosomal protein L23, Score: 88.68
# Recommendation 32: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glyceraldehyde-3-phosphate dehydrogenase, Score: 88.30
# Recommendation 33: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dystrophin, Score: 87.92
# Recommendation 34: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: utrophin, Score: 87.55
# Recommendation 35: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: signal transducer and activator of transcription 3, Score: 87.17
# Recommendation 36: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: interferon regulatory factor 4, Score: 86.79
# Recommendation 37: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cortactin, Score: 86.42
# Recommendation 38: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: occludin, Score: 86.04
# Recommendation 39: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vinculin, Score: 85.66
# Recommendation 40: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: paxillin, Score: 85.28
# Recommendation 41: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 62, Score: 84.91
# Recommendation 42: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: erythropoietin, Score: 84.53
# Recommendation 43: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 2, Score: 84.15
# Recommendation 44: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutaredoxin, Score: 83.77
# Recommendation 45: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: tyrosine hydroxylase, Score: 83.40
# Recommendation 46: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: renin, Score: 83.02
# Recommendation 47: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: interferon gamma, Score: 82.64
# Recommendation 48: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thyroid hormone receptor interactor 12, Score: 82.26
# Recommendation 49: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: monoamine oxidase A, Score: 81.89
# Recommendation 50: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: protein kinase C beta, Score: 81.51
# Recommendation 51: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: uncoupling protein 1, Score: 81.13
# Recommendation 52: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transferrin, Score: 80.75
# Recommendation 53: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nuclear receptor subfamily 4 group A member 1, Score: 80.38
# Recommendation 54: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: retinoic acid receptor alpha, Score: 80.00
# Recommendation 55: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurexin 1, Score: 79.62
# Recommendation 56: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histone deacetylase 2, Score: 79.25
# Recommendation 57: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ST8 alpha-N-acetyl-neuraminide alpha-2,8-sialyltransferase 2, Score: 78.87
# Recommendation 58: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vitamin D receptor, Score: 78.49
# Recommendation 59: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: methylenetetrahydrofolate reductase, Score: 78.11
# Recommendation 60: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: somatostatin, Score: 77.74
# Recommendation 61: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuraminidase 1, Score: 77.36
# Recommendation 62: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: BR serine/threonine kinase 2, Score: 76.98
# Recommendation 63: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: methyl-CpG binding protein 2, Score: 76.60
# Recommendation 64: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: chromodomain helicase DNA binding protein 8, Score: 76.23
# Recommendation 65: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: E1A binding protein p300, Score: 75.85
# Recommendation 66: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cadherin 2, Score: 75.47
# Recommendation 67: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myelin basic protein, Score: 75.09
# Recommendation 68: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: proliferating cell nuclear antigen, Score: 74.72
# Recommendation 69: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 8, Score: 74.34
# Recommendation 70: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: brain derived neurotrophic factor, Score: 73.96
# Recommendation 71: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: solute carrier family 6 member 4, Score: 73.58
# Recommendation 72: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dopamine receptor D3, Score: 73.21
# Recommendation 73: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphodiesterase 2A, Score: 72.83
# Recommendation 74: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prosaposin, Score: 72.45
# Recommendation 75: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: superoxide dismutase 1, Score: 72.08
# Recommendation 76: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: superoxide dismutase 2, Score: 71.70
# Recommendation 77: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatidylserine synthase 1, Score: 71.32
# Recommendation 78: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 3, Score: 70.94
# Recommendation 79: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: AKT serine/threonine kinase 1, Score: 70.57
# Recommendation 80: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: 5-hydroxytryptamine receptor 1B, Score: 70.19
# Recommendation 81: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: insulin receptor, Score: 69.81
# Recommendation 82: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: estrogen receptor 1, Score: 69.43
# Recommendation 83: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: Gilles de la Tourette syndrome, Score: 69.06
# Recommendation 84: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histidine decarboxylase, Score: 68.68
# Recommendation 85: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thioredoxin, Score: 68.30
# Recommendation 86: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 1, Score: 67.92
# Recommendation 87: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cholecystokinin, Score: 67.55
# Recommendation 88: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: syntaxin 1A, Score: 67.17
# Recommendation 89: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: heterogeneous nuclear ribonucleoprotein U, Score: 66.79
# Recommendation 90: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: microtubule associated serine/threonine kinase 3, Score: 66.42
# Recommendation 91: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate ionotropic receptor AMPA type subunit 2, Score: 66.04
# Recommendation 92: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuropilin 2, Score: 65.66
# Recommendation 93: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuropeptide Y, Score: 65.28
# Recommendation 94: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lysozyme, Score: 64.91
# Recommendation 95: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein A1, Score: 64.53
# Recommendation 96: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein B, Score: 64.15
# Recommendation 97: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: agrin, Score: 63.77
# Recommendation 98: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: plasminogen, Score: 63.40
# Recommendation 99: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: catechol-O-methyltransferase, Score: 63.02
# Recommendation 100: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ezrin, Score: 62.64
# Recommendation 101: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: radixin, Score: 62.26
# Recommendation 102: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: moesin, Score: 61.89
# Recommendation 103: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transcription factor 7, Score: 61.51
# Recommendation 104: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: steroid sulfatase, Score: 61.13
# Recommendation 105: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurofilament light chain, Score: 60.75
# Recommendation 106: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: DDHD domain containing 2, Score: 60.38
# Recommendation 107: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aggrecan, Score: 60.00
# Recommendation 108: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurocan, Score: 59.62
# Recommendation 109: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pericentrin, Score: 59.25
# Recommendation 110: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transferrin receptor, Score: 58.87
# Recommendation 111: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adhesion G protein-coupled receptor L3, Score: 58.49
# Recommendation 112: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: zinc finger protein 292, Score: 58.11
# Recommendation 113: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: placental growth factor, Score: 57.74
# Recommendation 114: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate ionotropic receptor AMPA type subunit 1, Score: 57.36
# Recommendation 115: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate metabotropic receptor 7, Score: 56.98
# Recommendation 116: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nuclear receptor corepressor 2, Score: 56.60
# Recommendation 117: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 1, Score: 56.23
# Recommendation 118: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: Aicardi syndrome, Score: 55.85
# Recommendation 119: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: activating transcription factor 4, Score: 55.47
# Recommendation 120: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pre-mRNA processing factor 4B, Score: 55.09
# Recommendation 121: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sulfotransferase, Score: 54.72
# Recommendation 122: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sulfite oxidase, Score: 54.34
# Recommendation 123: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: alpha-2-macroglobulin, Score: 53.96
# Recommendation 124: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatidylinositol glycan anchor biosynthesis class A, Score: 53.58
# Recommendation 125: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myeloperoxidase, Score: 53.21
# Recommendation 126: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: telomerase RNA component, Score: 52.83
# Recommendation 127: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: CD40 ligand, Score: 52.45
# Recommendation 128: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aryl hydrocarbon receptor nuclear translocator, Score: 52.08
# Recommendation 129: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: 4-aminobutyrate aminotransferase, Score: 51.70
# Recommendation 130: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: N
Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: reelin, Score: 9.43
# Recommendation 242: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroplastin, Score: 9.06
# Recommendation 243: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: doublecortin, Score: 8.68
# Recommendation 244: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: metallothionein 3, Score: 8.30
# Recommendation 245: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: beclin 1, Score: 7.92
# Recommendation 246: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: bridging integrator 1, Score: 7.55
# Recommendation 247: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dynamin 2, Score: 7.17
# Recommendation 248: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: FIG4 phosphoinositide 5-phosphatase, Score: 6.79
# Recommendation 249: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myotubularin 1, Score: 6.42
# Recommendation 250: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: SPG11 vesicle trafficking associated, spatacsin, Score: 6.04
# Recommendation 251: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sequestosome 1, Score: 5.66
# Recommendation 252: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TBC1 domain family member 20, Score: 5.28
# Recommendation 253: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TSC complex subunit 1, Score: 4.91
# Recommendation 254: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ubiquilin 2, Score: 4.53
# Recommendation 255: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vacuolar ATPase assembly factor VMA21, Score: 4.15
# Recommendation 256: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 45, Score: 3.77
# Recommendation 257: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 47, Score: 3.40
# Recommendation 258: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sex hormone binding globulin, Score: 3.02
# Recommendation 259: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: haptoglobin, Score: 2.64
# Recommendation 260: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: secretin, Score: 2.26
# Recommendation 261: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: fatty acid amide hydrolase, Score: 1.89
# Recommendation 262: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cell division cycle 42, Score: 1.51
# Recommendation 263: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: makorin ring finger protein 3, Score: 1.13
# Recommendation 264: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: replication factor C subunit 1, Score: 0.75
# Recommendation 265: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: CF transmembrane conductance regulator, Score: 0.38

# %%
best_k = best_params['k']
print(f'O valor de k selecionado é: {best_k}')
# Out:
# O valor de k selecionado é: 10

# %% [markdown]
# Autism-Focused Split (Single Author per Test)

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import train_test_split, GridSearchCV
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score

# Load dataset
data = pd.read_csv('all_articles_files_names_merge_final7.csv', sep=',')

# Keep one row for each author with the disease 'Autistic disorder' for testing
test_data_autistic = data[data['author/disease'] == 'Autistic disorder'].groupby('id').head(1)
train_data_autistic = data.drop(test_data_autistic.index)

# For the test dataset, keep only one example for each author with 'Autistic disorder'
# All examples for other diseases go to training
test_data_autistic = test_data_autistic.groupby('id').head(1)

# For authors without 'Autistic disorder', keep one example for testing and the rest for training
test_data_other = data[data['author/disease'] != 'Autistic disorder'].groupby('id').head(1)
train_data_other = data.drop(test_data_other.index)

# Combine the test data for 'Autistic disorder' and others
test_data = pd.concat([test_data_autistic, test_data_other])

# Define the reader
reader = Reader(rating_scale=(0, 100))

# Convert the modified DataFrames to the format expected by Surprise
train_dataset = Dataset.load_from_df(train_data_other[['id', 'gene', 'article_count']], reader=reader)
test_dataset = Dataset.load_from_df(test_data[['id', 'gene', 'article_count']], reader=reader)

# Random split 80/20 for the training dataset
trainset, _ = train_test_split(train_dataset, test_size=0.2)

# Define the parameter space for GridSearch
param_grid = {'k': [10, 20, 30]}

# Perform the grid search
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(train_dataset)

# Access the best found parameters
best_params = grid_search.best_params['rmse']

# Train the model with the training set using the best parameters
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Make predictions on the test set
testset = test_dataset.build_full_trainset().build_testset()
if len(testset) == 0:
    print("Test set is empty. Please check the data and the test set creation process.")
else:
    predictions = model.test(testset)

    # Calculate evaluation metrics
    accuracy.rmse(predictions)
    accuracy.mae(predictions)

    # Retrieve predicted and actual ratings
    predicted_ratings = [pred.est for pred in predictions]
    true_ratings = [pred.r_ui for pred in predictions]

    # Convert ratings to binary labels based on the threshold
    threshold = 3.5
    predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
    true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

    # Calculate precision, recall, and F1-score metrics
    precision = precision_score(true_labels, predicted_labels)
    recall = recall_score(true_labels, predicted_labels)
    f1 = f1_score(true_labels, predicted_labels)

    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1}')


# Target author for recommendation
author_id = 4817

# Retrieve all genes mentioned by the target author
genes_target_author = data[data['id'] == author_id]['gene'].unique()

# Make predictions for genes not mentioned by the target author.
genes_not_mentioned = data[~data['gene'].isin(genes_target_author)]['gene'].unique()

predictions = []

for gene in genes_not_mentioned:
    prediction = model.predict(author_id, gene)
    predictions.append((author_id, gene, prediction.est))

# Sort the predictions in descending order
sorted_predictions = sorted(predictions, key=lambda x: x[2], reverse=True)

# Retrieve the author's name
author_name = data[data['id'] == author_id]['author/disease'].iloc[0]

# Calculate scores based on the recommendation position
# The higher the position, the lower the score
total_recommendations = len(sorted_predictions)
scores = [(total_recommendations - i) / total_recommendations * 100 for i in range(total_recommendations)]

# Display normalized scores
for i, (author, gene, _) in enumerate(sorted_predictions):
    print(f'Recommendation {i+1}: Author ID: {author}, Author Name: {author_name}, Gene: {gene}, Score: {scores[i]:.2f}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 2.6940
# MAE:  1.4572
# Precision: 0.5054347826086957
# Recall: 1.0
# F1 Score: 0.6714801444043321
# Recommendation 1: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: oxytocin receptor, Score: 100.00
# Recommendation 2: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: catalase, Score: 99.62
# Recommendation 3: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ceruloplasmin, Score: 99.25
# Recommendation 4: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: islet cell autoantigen 1, Score: 98.87
# Recommendation 5: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: homeobox A1, Score: 98.49
# Recommendation 6: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histatin 1, Score: 98.11
# Recommendation 7: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 3, Score: 97.74
# Recommendation 8: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: arginine vasopressin, Score: 97.36
# Recommendation 9: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: translocator protein, Score: 96.98
# Recommendation 10: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: parvalbumin, Score: 96.60
# Recommendation 11: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prolactin, Score: 96.23
# Recommendation 12: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: leptin, Score: 95.85
# Recommendation 13: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: androgen receptor, Score: 95.47
# Recommendation 14: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatase and tensin homolog, Score: 95.09
# Recommendation 15: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: C-reactive protein, Score: 94.72
# Recommendation 16: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nerve growth factor, Score: 94.34
# Recommendation 17: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: epidermal growth factor, Score: 93.96
# Recommendation 18: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: resistin, Score: 93.58
# Recommendation 19: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apelin, Score: 93.21
# Recommendation 20: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: albumin, Score: 92.83
# Recommendation 21: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: biotinidase, Score: 92.45
# Recommendation 22: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: synaptophysin, Score: 92.08
# Recommendation 23: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenosine deaminase, Score: 91.70
# Recommendation 24: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenylosuccinate lyase, Score: 91.32
# Recommendation 25: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glyceraldehyde-3-phosphate dehydrogenase, Score: 90.94
# Recommendation 26: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dystrophin, Score: 90.57
# Recommendation 27: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene
Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hyaluronan and proteoglycan link protein 1, Score: 5.28
# Recommendation 253: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transcription factor EB, Score: 4.91
# Recommendation 254: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: platelet factor 4, Score: 4.53
# Recommendation 255: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: high mobility group box 1, Score: 4.15
# Recommendation 256: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myogenin, Score: 3.77
# Recommendation 257: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: presenilin 1, Score: 3.40
# Recommendation 258: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: afamin, Score: 3.02
# Recommendation 259: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phospholipase A2 group VI, Score: 2.64
# Recommendation 260: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: uncoupling protein 2, Score: 2.26
# Recommendation 261: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: CF transmembrane conductance regulator, Score: 1.89
# Recommendation 262: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: steroidogenic acute regulatory protein, Score: 1.51
# Recommendation 263: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thymic stromal lymphopoietin, Score: 1.13
# Recommendation 264: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: beclin 1, Score: 0.75
# Recommendation 265: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sex hormone binding globulin, Score: 0.38

# %%
best_k = best_params['k']
print(f'O valor de k selecionado é: {best_k}')
# Out:
# O valor de k selecionado é: 10

# %% [markdown]
# Disease-Based Split

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import train_test_split
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score
from surprise.model_selection import GridSearchCV

# Load dataset
data = pd.read_csv('all_articles_files_names_merge_final6.csv', sep=',')

# Define the reader
reader = Reader(rating_scale=(0, 100))

# Convert the DataFrame to the format expected by Surprise
dataset = Dataset.load_from_df(data[['id', 'gene', 'n_articles']], reader=reader)

# Filter examples where the disease is "Autistic disorder" for the test set
test_data = data[data['author/disease'].str.contains('Autistic disorder')]

# Filter examples where the disease is not "Autistic disorder" for the training set
train_data = data[~data['author/disease'].str.contains('Autistic disorder')]

# Convert the training and test data to the appropriate Surprise sets
trainset = dataset.build_full_trainset()
testset = [(row['id'], row['gene'], row['n_articles']) for index, row in test_data.iterrows()]

# Define the parameter space for GridSearch
param_grid = {'k': [10, 20, 30]}

# Perform grid search with cross-validation
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(dataset)

# Access the best found parameters
best_params = grid_search.best_params['rmse']

# Train the model with the training set using the best parameters
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Make predictions on the test set
predictions = model.test(testset)

# Calculate evaluation metrics
accuracy.rmse(predictions)
accuracy.mae(predictions)

# Retrieve predicted and actual ratings
predicted_ratings = [pred.est for pred in predictions]
true_ratings = [pred.r_ui for pred in predictions]

# Convert ratings to binary labels based on the threshold
threshold = 3.5
predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

# Calculate precision, recall, and F1-score metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Target author for recommendation
author_id = 4817

# Retrieve all genes mentioned by the target author
genes_target_author = data[data['id'] == author_id]['gene'].unique()

# Make predictions for genes not mentioned by the target author.
genes_not_mentioned = data[~data['gene'].isin(genes_target_author)]['gene'].unique()

predictions = []

for gene in genes_not_mentioned:
    prediction = model.predict(author_id, gene)
    predictions.append((author_id, gene, prediction.est))

# Sort the predictions in descending order
sorted_predictions = sorted(predictions, key=lambda x: x[2], reverse=True)

# Retrieve the author's name
author_name = data[data['id'] == author_id]['author/disease'].iloc[0]

# Calculate scores based on the recommendation position
# The higher the position, the lower the score
total_recommendations = len(sorted_predictions)
scores = [(total_recommendations - i) / total_recommendations * 100 for i in range(total_recommendations)]

# Display normalized scores
for i, (author, gene, _) in enumerate(sorted_predictions):
    print(f'Recommendation {i+1}: Author ID: {author}, Author Name: {author_name}, Gene: {gene}, Score: {scores[i]:.2f}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8824
# MAE:  0.3784
# Precision: 0.6382978723404256
# Recall: 0.9090909090909091
# F1 Score: 0.75
# Recommendation 1: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dermokine, Score: 100.00
# Recommendation 2: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: angiotensin converting enzyme 2, Score: 99.62
# Recommendation 3: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TSR2 ribosome maturation factor, Score: 99.25
# Recommendation 4: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myelin oligodendrocyte glycoprotein, Score: 98.87
# Recommendation 5: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cysteinyl leukotriene receptor 1, Score: 98.49
# Recommendation 6: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cathepsin S, Score: 98.11
# Recommendation 7: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: kinectin 1, Score: 97.74
# Recommendation 8: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pannexin 2, Score: 97.36
# Recommendation 9: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: N-acetyltransferase 10, Score: 96.98
# Recommendation 10: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cholesteryl ester transfer protein, Score: 96.60
# Recommendation 11: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dopamine receptor D1, Score: 96.23
# Recommendation 12: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: corticotropin releasing hormone receptor 1, Score: 95.85
# Recommendation 13: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein A1, Score: 95.47
# Recommendation 14: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vimentin, Score: 95.09
# Recommendation 15: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lipoprotein(a), Score: 94.72
# Recommendation 16: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein B, Score: 94.34
# Recommendation 17: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenosine deaminase, Score: 93.96
# Recommendation 18: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adenylosuccinate lyase, Score: 93.58
# Recommendation 19: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cystathionine beta-synthase, Score: 93.21
# Recommendation 20: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: MORC family CW-type zinc finger 1, Score: 92.83
# Recommendation 21: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aminoacylase 1, Score: 92.45
# Recommendation 22: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cell division cycle 42, Score: 92.08
# Recommendation 23: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lipopolysaccharide binding protein, Score: 91.70
# Recommendation 24: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: parathyroid hormone, Score: 91.32
# Recommendation 25: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myelin basic protein, Score: 90.94
# Recommendation 26: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: catechol-O-methyltransferase, Score: 90.57
# Recommendation 27: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: synapsin I, Score: 90.19
# Recommendation 28: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: mitogen-activated protein kinase 3, Score: 89.81
# Recommendation 29: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: agmatinase, Score: 89.43
# Recommendation 30: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lysozyme, Score: 89.06
# Recommendation 31: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: N-acylethanolamine acid amidase, Score: 88.68
# Recommendation 32: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aggrecan, Score: 88.30
# Recommendation 33: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurocan, Score: 87.92
# Recommendation 34: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: agrin, Score: 87.55
# Recommendation 35: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thioredoxin, Score: 87.17
# Recommendation 36: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: BR serine/threonine kinase 2, Score: 86.79
# Recommendation 37: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: stomatin, Score: 86.42
# Recommendation 38: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: low density lipoprotein receptor, Score: 86.04
# Recommendation 39: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: doublecortin, Score: 85.66
# Recommendation 40: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hexokinase 1, Score: 85.28
# Recommendation 41: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prolactin, Score: 84.91
# Recommendation 42: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pre-mRNA processing factor 4B, Score: 84.53
# Recommendation 43: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate metabotropic receptor 5, Score: 84.15
# Recommendation 44: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: C-reactive protein, Score: 83.77
# Recommendation 45: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: catalase, Score: 83.40
# Recommendation 46: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: fibroblast growth factor 14, Score: 83.02
# Recommendation 47: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ezrin, Score: 82.64
# Recommendation 48: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: radixin, Score: 82.26
# Recommendation 49: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: moesin, Score: 81.89
# Recommendation 50: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: leptin, Score: 81.51
# Recommendation 51: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: fragile X messenger ribonucleoprotein 1, Score: 81.13
# Recommendation 52: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: androgen receptor, Score: 80.75
# Recommendation 53: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatase and tensin homolog, Score: 80.38
# Recommendation 54: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate ionotropic receptor NMDA type subunit 2B, Score: 80.00
# Recommendation 55: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: albumin, Score: 79.62
# Recommendation 56: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: synaptophysin, Score: 79.25
# Recommendation 57: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myoglobin, Score: 78.87
# Recommendation 58: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: huntingtin, Score: 78.49
# Recommendation 59: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: oxytocin receptor, Score: 78.11
# Recommendation 60: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutaminyl-peptide cyclotransferase, Score: 77.74
# Recommendation 61: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sulfotransferase, Score: 77.36
# Recommendation 62: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: tyrosine hydroxylase, Score: 76.98
# Recommendation 63: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein E, Score: 76.60
# Recommendation 64: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: estrogen receptor 1, Score: 76.23
# Recommendation 65: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ceruloplasmin, Score: 75.85
# Recommendation 66: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurexophilin 1, Score: 75.47
# Recommendation 67: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: islet cell autoantigen 1, Score: 75.09
# Recommendation 68: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: homeobox A1, Score: 74.72
# Recommendation 69: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: statherin, Score: 74.34
# Recommendation 70: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histatin 1, Score: 73.96
# Recommendation 71: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: translocator protein, Score: 73.58
# Recommendation 72: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: lactase, Score: 73.21
# Recommendation 73: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TBC1 domain family member 7, Score: 72.83
# Recommendation 74: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: gastrin, Score: 72.45
# Recommendation 75: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: epidermal growth factor, Score: 72.08
# Recommendation 76: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: resistin, Score: 71.70
# Recommendation 77: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apelin, Score: 71.32
# Recommendation 78: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: SH3 and multiple ankyrin repeat domains 3, Score: 70.94
# Recommendation 79: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: secretin, Score: 70.57
# Recommendation 80: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ribosomal protein L23, Score: 70.19
# Recommendation 81: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glyceraldehyde-3-phosphate dehydrogenase, Score: 69.81
# Recommendation 82: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dystrophin, Score: 69.43
# Recommendation 83: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: utrophin, Score: 69.06
# Recommendation 84: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: signal transducer and activator of transcription 3, Score: 68.68
# Recommendation 85: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: interferon regulatory factor 4, Score: 68.30
# Recommendation 86: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: occludin, Score: 67.92
# Recommendation 87: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vinculin, Score: 67.55
# Recommendation 88: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: paxillin, Score: 67.17
# Recommendation 89: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: erythropoietin, Score: 66.79
# Recommendation 90: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutaredoxin, Score: 66.42
# Recommendation 91: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: interferon gamma, Score: 66.04
# Recommendation 92: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thyroid hormone receptor interactor 12, Score: 65.66
# Recommendation 93: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: protein kinase C beta, Score: 65.28
# Recommendation 94: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: uncoupling protein 1, Score: 64.91
# Recommendation 95: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transferrin, Score: 64.53
# Recommendation 96: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histone deacetylase 2, Score: 64.15
# Recommendation 97: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: methyl-CpG binding protein 2, Score: 63.77
# Recommendation 98: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: chromodomain helicase DNA binding protein 8, Score: 63.40
# Recommendation 99: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: proliferating cell nuclear antigen, Score: 63.02
# Recommendation 100: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 8, Score: 62.64
# Recommendation 101: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: solute carrier family 6 member 4, Score: 62.26
# Recommendation 102: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dopamine receptor D3, Score: 61.89
# Recommendation 103: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphodiesterase 2A, Score: 61.51
# Recommendation 104: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: superoxide dismutase 1, Score: 61.13
# Recommendation 105: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: AKT serine/threonine kinase 1, Score: 60.75
# Recommendation 106: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: 5-hydroxytryptamine receptor 1B, Score: 60.38
# Recommendation 107: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: insulin receptor, Score: 60.00
# Recommendation 108: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: Gilles de la Tourette syndrome, Score: 59.62
# Recommendation 109: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histidine decarboxylase, Score: 59.25
# Recommendation 110: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 1, Score: 58.87
# Recommendation 111: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cholecystokinin, Score: 58.49
# Recommendation 112: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: syntaxin 1A, Score: 58.11
# Recommendation 113: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: heterogeneous nuclear ribonucleoprotein U, Score: 57.74
# Recommendation 114: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuropilin 2, Score: 57.36
# Recommendation 115: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuropeptide Y, Score: 56.98
# Recommendation 116: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: plasminogen, Score: 56.60
# Recommendation 117: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transcription factor 7, Score: 56.23
# Recommendation 118: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: steroid sulfatase, Score: 55.85
# Recommendation 119: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurofilament light chain, Score: 55.47
# Recommendation 120: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: fatty acid amide hydrolase, Score: 55.09
# Recommendation 121: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transferrin receptor, Score: 54.72
# Recommendation 122: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: adhesion G protein-coupled receptor L3, Score: 54.34
# Recommendation 123: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: zinc finger protein 292, Score: 53.96
# Recommendation 124: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: placental growth factor, Score: 53.58
# Recommendation 125: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nuclear receptor corepressor 2, Score: 53.21
# Recommendation 126: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 1, Score: 52.83
# Recommendation 127: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: activating transcription factor 4, Score: 52.45
# Recommendation 128: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sulfite oxidase, Score: 52.08
# Recommendation 129: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: alpha-2-macroglobulin, Score: 51.70
# Recommendation 130: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatidylinositol glycan anchor biosynthesis class A, Score: 51.32
# Recommendation 131: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myeloperoxidase, Score: 50.94
# Recommendation 132: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: telomerase RNA component, Score: 50.57
# Recommendation 133: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: CD40 ligand, Score: 50.19
# Recommendation 134: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aryl hydrocarbon receptor nuclear translocator, Score: 49.81
# Recommendation 135: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: 4-aminobutyrate aminotransferase, Score: 49.43
# Recommendation 136: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: N-glycanase 1, Score: 49.06
# Recommendation 137: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: short stature homeobox, Score: 48.68
# Recommendation 138: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dopamine receptor D4, Score: 48.30
# Recommendation 139: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: poly(A)-specific ribonuclease, Score: 47.92
# Recommendation 140: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vasoactive intestinal peptide, Score: 47.55
# Recommendation 141: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate decarboxylase 1, Score: 47.17
# Recommendation 142: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: fatty acid binding protein 7, Score: 46.79
# Recommendation 143: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate metabotropic receptor 3, Score: 46.42
# Recommendation 144: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: proenkephalin, Score: 46.04
# Recommendation 145: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: 7-dehydrocholesterol reductase, Score: 45.66
# Recommendation 146: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thyroglobulin, Score: 45.28
# Recommendation 147: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prion protein, Score: 44.91
# Recommendation 148: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: citrate synthase, Score: 44.53
# Recommendation 149: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphoglycerate kinase 1, Score: 44.15
# Recommendation 150: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transthyretin, Score: 43.77
# Recommendation 151: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hypoparathyroidism, Score: 43.40
# Recommendation 152: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: apolipoprotein C3, Score: 43.02
# Recommendation 153: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: clusterin, Score: 42.64
# Recommendation 154: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: monoamine oxidase B, Score: 42.26
# Recommendation 155: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sphingosine-1-phosphate receptor 1, Score: 41.89
# Recommendation 156: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: angiopoietin 2, Score: 41.51
# Recommendation 157: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pentraxin 3, Score: 41.13
# Recommendation 158: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurogranin, Score: 40.75
# Recommendation 159: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: contactin 5, Score: 40.38
# Recommendation 160: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: C-X-C motif chemokine ligand 10, Score: 40.00
# Recommendation 161: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: diabetic nephropathy, Score: 39.62
# Recommendation 162: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: amphiphysin, Score: 39.25
# Recommendation 163: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: progesterone receptor, Score: 38.87
# Recommendation 164: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hepatocyte growth factor, Score: 38.49
# Recommendation 165: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: aquaporin 4, Score: 38.11
# Recommendation 166: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cadherin 5, Score: 37.74
# Recommendation 167: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: synaptopodin, Score: 37.36
# Recommendation 168: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glycogen synthase kinase 3 beta, Score: 36.98
# Recommendation 169: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: titin, Score: 36.60
# Recommendation 170: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: interleukin 1 beta, Score: 36.23
# Recommendation 171: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: golgin A4, Score: 35.85
# Recommendation 172: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vasoactive intestinal peptide receptor 2, Score: 35.47
# Recommendation 173: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutathione peroxidase 1, Score: 35.09
# Recommendation 174: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hyaluronan and proteoglycan link protein 1, Score: 34.72
# Recommendation 175: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cadherin related 23, Score: 34.34
# Recommendation 176: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cathepsin B, Score: 33.96
# Recommendation 177: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: retinol binding protein 4, Score: 33.58
# Recommendation 178: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: transcription factor EB, Score: 33.21
# Recommendation 179: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: platelet factor 4, Score: 32.83
# Recommendation 180: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: kynurenine 3-monooxygenase, Score: 32.45
# Recommendation 181: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: hydroxycarboxylic acid receptor 2, Score: 32.08
# Recommendation 182: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cyclin D1, Score: 31.70
# Recommendation 183: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: replication factor C subunit 1, Score: 31.32
# Recommendation 184: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuronal pentraxin receptor, Score: 30.94
# Recommendation 185: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuronal pentraxin 1, Score: 30.57
# Recommendation 186: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuronal pentraxin 2, Score: 30.19
# Recommendation 187: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: high mobility group box 1, Score: 29.81
# Recommendation 188: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myogenin, Score: 29.43
# Recommendation 189: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: presenilin 1, Score: 29.06
# Recommendation 190: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: presenilin 2, Score: 28.68
# Recommendation 191: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurofilament heavy chain, Score: 28.30
# Recommendation 192: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: afamin, Score: 27.92
# Recommendation 193: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: beta-secretase 1, Score: 27.55
# Recommendation 194: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ribosomal protein L13a, Score: 27.17
# Recommendation 195: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phospholipase A2 group VI, Score: 26.79
# Recommendation 196: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: decorin, Score: 26.42
# Recommendation 197: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurotensin, Score: 26.04
# Recommendation 198: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: uncoupling protein 2, Score: 25.66
# Recommendation 199: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: selenoprotein P, Score: 25.28
# Recommendation 200: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: kinesin family member 5A, Score: 24.91
# Recommendation 201: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: CF transmembrane conductance regulator, Score: 24.53
# Recommendation 202: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: Cdc42 guanine nucleotide exchange factor 9, Score: 24.15
# Recommendation 203: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cytoplasmic FMR1 interacting protein 2, Score: 23.77
# Recommendation 204: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: small nucleolar RNA host gene 11, Score: 23.40
# Recommendation 205: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: maternally expressed 3, Score: 23.02
# Recommendation 206: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: steroidogenic acute regulatory protein, Score: 22.64
# Recommendation 207: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thymic stromal lymphopoietin, Score: 22.26
# Recommendation 208: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: reelin, Score: 21.89
# Recommendation 209: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroplastin, Score: 21.51
# Recommendation 210: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: metallothionein 3, Score: 21.13
# Recommendation 211: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: beclin 1, Score: 20.75
# Recommendation 212: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: bridging integrator 1, Score: 20.38
# Recommendation 213: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: dynamin 2, Score: 20.00
# Recommendation 214: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: FIG4 phosphoinositide 5-phosphatase, Score: 19.62
# Recommendation 215: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: myotubularin 1, Score: 19.25
# Recommendation 216: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: SPG11 vesicle trafficking associated, spatacsin, Score: 18.87
# Recommendation 217: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sequestosome 1, Score: 18.49
# Recommendation 218: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TBC1 domain family member 20, Score: 18.11
# Recommendation 219: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: TSC complex subunit 1, Score: 17.74
# Recommendation 220: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ubiquilin 2, Score: 17.36
# Recommendation 221: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vacuolar ATPase assembly factor VMA21, Score: 16.98
# Recommendation 222: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 45, Score: 16.60
# Recommendation 223: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 47, Score: 16.23
# Recommendation 224: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: haptoglobin, Score: 15.85
# Recommendation 225: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: WD repeat domain 62, Score: 15.47
# Recommendation 226: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: caspase 3, Score: 15.09
# Recommendation 227: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: DDHD domain containing 2, Score: 14.72
# Recommendation 228: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: brain derived neurotrophic factor, Score: 14.34
# Recommendation 229: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neurexin 1, Score: 13.96
# Recommendation 230: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate ionotropic receptor AMPA type subunit 2, Score: 13.58
# Recommendation 231: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nerve growth factor, Score: 13.21
# Recommendation 232: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: E1A binding protein p300, Score: 12.83
# Recommendation 233: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cadherin 2, Score: 12.45
# Recommendation 234: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 2, Score: 12.08
# Recommendation 235: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ectodermal-neural cortex 1, Score: 11.70
# Recommendation 236: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: gephyrin, Score: 11.32
# Recommendation 237: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: thymoma, Score: 10.94
# Recommendation 238: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: somatostatin, Score: 10.57
# Recommendation 239: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuroligin 3, Score: 10.19
# Recommendation 240: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: biotinidase, Score: 9.81
# Recommendation 241: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: vitamin D receptor, Score: 9.43
# Recommendation 242: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: sex hormone binding globulin, Score: 9.06
# Recommendation 243: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: renin, Score: 8.68
# Recommendation 244: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: parvalbumin, Score: 8.30
# Recommendation 245: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: histamine N-methyltransferase, Score: 7.92
# Recommendation 246: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: Aicardi syndrome, Score: 7.55
# Recommendation 247: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: makorin ring finger protein 3, Score: 7.17
# Recommendation 248: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: pericentrin, Score: 6.79
# Recommendation 249: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neural cell adhesion molecule 1, Score: 6.42
# Recommendation 250: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate ionotropic receptor AMPA type subunit 1, Score: 6.04
# Recommendation 251: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: glutamate metabotropic receptor 7, Score: 5.66
# Recommendation 252: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: neuraminidase 1, Score: 5.28
# Recommendation 253: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: monoamine oxidase A, Score: 4.91
# Recommendation 254: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: cortactin, Score: 4.53
# Recommendation 255: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: nuclear receptor subfamily 4 group A member 1, Score: 4.15
# Recommendation 256: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: microtubule associated serine/threonine kinase 3, Score: 3.77
# Recommendation 257: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: ST8 alpha-N-acetyl-neuraminide alpha-2,8-sialyltransferase 2, Score: 3.40
# Recommendation 258: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: retinoic acid receptor alpha, Score: 3.02
# Recommendation 259: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: prosaposin, Score: 2.64
# Recommendation 260: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: superoxide dismutase 2, Score: 2.26
# Recommendation 261: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: arginine vasopressin, Score: 1.89
# Recommendation 262: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: methylenetetrahydrofolate reductase, Score: 1.51
# Recommendation 263: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: phosphatidylserine synthase 1, Score: 1.13
# Recommendation 264: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: telomerase reverse transcriptase, Score: 0.75
# Recommendation 265: Author ID: 4817, Author Name: Liu S/Autism spectrum disorder, Gene: complement C9, Score: 0.38

# %%
best_k = best_params['k']
print(f'O valor de k selecionado é: {best_k}')
# Out:
# O valor de k selecionado é: 30
