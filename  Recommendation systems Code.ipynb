# %% [markdown]
# Random Split 80/20

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import train_test_split, GridSearchCV
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score

#Load dataset
#Make sure to replace 'all_articles_files_names_merge_final3.csv' with the correct path to your CSV file.
data = pd.read_csv('all_articles_files_names_merge_final3.csv', sep=',')

# Define the reader
reader = Reader(rating_scale=(1, data['article_count'].max()))

# Convert the DataFrame to the format expected by Surprise
dataset = Dataset.load_from_df(data[['id', 'gene', 'article_count']], reader=reader)

# Random split 80/20
trainset, testset = train_test_split(dataset, test_size=0.2)

# Define the parameter space for GridSearch
param_grid = {'k': [10, 20, 30]}

# Perform the grid search
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(dataset)

# Access the best found parameters
best_params = grid_search.best_params['rmse']

# Train the model with the training set using the best parameters
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Make predictions on the test set
predictions = model.test(testset)

# Calculate evaluation metrics
accuracy.rmse(predictions)
accuracy.mae(predictions)

# Retrieve predicted and actual ratings
predicted_ratings = [pred.est for pred in predictions]
true_ratings = [pred.r_ui for pred in predictions]

# Convert ratings to binary labels based on the threshold
threshold = 3.5
predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

# Calculate precision, recall, and F1-score metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Target author for recommendation
autor_id = 5177

# Retrieve all genes mentioned by the target author
genes_autor_alvo = data[data['id'] == autor_id]['gene'].unique()

# Make predictions for genes not mentioned by the target author.
genes_nao_mencionados = data[~data['gene'].isin(genes_autor_alvo)]['gene'].unique()

previsoes = []

for gene in genes_nao_mencionados:
    predicao = model.predict(autor_id, gene)
    previsoes.append((autor_id, gene, predicao.est))

# Sort the predictions in descending order
previsoes_ordenadas = sorted(previsoes, key=lambda x: x[2], reverse=True)

# Retrieve the author's name
autor_nome = data[data['id'] == autor_id]['author/disease'].iloc[0]

# Display the top predictions
for autor, gene, pontuacao in previsoes_ordenadas:
    print(f'ID from author: {autor}, author name: {autor_nome}, Gene: {gene}, Score: {pontuacao}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9036
# MAE:  0.3478
# Precision: 0.7148217636022514
# Recall: 0.9525
# F1 Score: 0.8167202572347266
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: kinectin 1, Pontuação: 10.074074074074074
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: TSR2 ribosome maturation factor, Pontuação: 10.074074074074074
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: corticotropin releasing hormone receptor 1, Pontuação: 10.074074074074074
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: dermokine, Pontuação: 10.074074074074074
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: prolactin, Pontuação: 9.916104759112674
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: androgen receptor, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: glucagon, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: myelin basic protein, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: catechol-O-methyltransferase, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: hexokinase 1, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: N-acylethanolamine acid amidase, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: fragile X messenger ribonucleoprotein 1, Pontuação: 9.583333333333332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: aryl hydrocarbon receptor, Pontuação: 6.126350519924817
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: fibroblast growth factor 14, Pontuação: 5.833333333333333
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: leptin, Pontuação: 5.670321118991332
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: catalase, Pontuação: 5.5
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: dopamine receptor D1, Pontuação: 5.5
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: somatostatin, Pontuação: 5.434019734019734
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: neuroligin 3, Pontuação: 5.428571428571429
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: ne
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: sex hormone binding globulin, Pontuação: 3.585308908045977
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: glutathione peroxidase 4, Pontuação: 3.097402597402597
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: glutaminase, Pontuação: 2.4242424242424243
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: neuraminidase 1, Pontuação: 1.0740740740740744
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: arginine vasopressin, Pontuação: 1
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: nuclear receptor subfamily 4 group A member 1, Pontuação: 1
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: prosaposin, Pontuação: 1
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: microtubule associated serine/threonine kinase 3, Pontuação: 1
# ID do Autor: 5177, Nome do Autor: Martins RN/Disease of mental health, Gene: DDHD domain containing 2, Pontuação: 1

# %% [markdown]
# Autism-Focused Split (Single Author per Test)

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import GridSearchCV
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score

# Carregar os dados do dataset
# Certifique-se de substituir 'all_articles_files_names_merge.csv' pelo caminho correto do seu arquivo CSV
data = pd.read_csv('all_articles_files_names_merge_final3.csv', sep=',')

# Definir o leitor
reader = Reader(rating_scale=(1, data['article_count'].max()))

# Converter o DataFrame para o formato esperado pelo Surprise
dataset = Dataset.load_from_df(data[['id', 'gene', 'article_count']], reader=reader)

# Filtrar os exemplos onde a doença é "Autistic disorder"
autistic_data = data[data['author/disease'].str.contains('Autistic disorder')]

# Filtrar os exemplos onde a doença não é "Autistic disorder"
non_autistic_data = data[~data['author/disease'].str.contains('Autistic disorder')]

# Lista para armazenar os IDs dos autores já utilizados como teste
test_author_ids = []

# Lista para armazenar os dados do conjunto de treino
train_data = []

# Lista para armazenar os dados do conjunto de teste
testset_autistic = []

# Loop para selecionar um exemplo de cada autor com a doença "Autistic disorder" para teste e o resto para treino
for index, row in autistic_data.iterrows():
    author_id = row['id']
    if author_id not in test_author_ids:
        test_author_ids.append(author_id)
        test_data = row[['id', 'gene', 'article_count']].tolist()
        test_data[2] = float(test_data[2])  # Convert the article_count to a float value
        # Add a placeholder for the fourth element (left empty)
        test_data.append(None)
        test_data_tuple = tuple(test_data)
        testset_autistic.append(test_data_tuple)
    else:
        train_data.append(row[['id', 'gene', 'article_count']].tolist())

# Combinar os dados de treino não-autistas com o restante dos dados de treino autistas
train_data.extend(non_autistic_data[['id', 'gene', 'article_count']].values.tolist())

# Converter os dados de treino e teste para os conjuntos apropriados do Surprise
trainset = dataset.build_full_trainset()
trainset.raw_ratings = train_data
testset = dataset.construct_testset(testset_autistic)

# Definir o espaço de parâmetros para o GridSearch
param_grid = {'k': [10, 20, 30]}

# Realizar a busca em grid com cross-validation
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(dataset)

# Acessar os melhores parâmetros encontrados
best_params = grid_search.best_params['rmse']

# Treinar o modelo com o conjunto de treino usando os melhores parâmetros
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Fazer previsões no conjunto de teste
predictions = model.test(testset)

# Calcular as métricas de avaliação
accuracy.rmse(predictions)
accuracy.mae(predictions)

# Obter as classificações previstas e reais
predicted_ratings = [pred.est for pred in predictions]
true_ratings = [pred.r_ui for pred in predictions]

# Converter as classificações em rótulos binários com base no limiar
threshold = 3.5
predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

# Calcular as métricas de precisão, recall e F1-score
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Autor alvo para recomendação
autor_id = 4817

# Obter todos os genes mencionados pelo autor alvo
genes_autor_alvo = data[data['id'] == autor_id]['gene'].unique()

# Realizar as previsões para os genes não mencionados pelo autor alvo
genes_nao_mencionados = data[~data['gene'].isin(genes_autor_alvo)]['gene'].unique()

previsoes = []

for gene in genes_nao_mencionados:
    predicao = model.predict(autor_id, gene)
    previsoes.append((autor_id, gene, predicao.est))

# Ordenar as previsões em ordem decrescente
previsoes_ordenadas = sorted(previsoes, key=lambda x: x[2], reverse=True)

# Obter o nome do autor
autor_nome = data[data['id'] == autor_id]['author/disease'].iloc[0]

# Exibir as melhores previsões
for autor, gene, pontuacao in previsoes_ordenadas:
    print(f'ID do Autor: {autor}, Nome do Autor: {autor_nome}, Gene: {gene}, Pontuação: {pontuacao}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8231
# MAE:  0.3373
# Precision: 0.5384615384615384
# Recall: 0.875
# F1 Score: 0.6666666666666667
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: dermokine, Pontuação: 9.778801843317972
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: angiotensin converting enzyme 2, Pontuação: 8.571428571428571
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: TSR2 ribosome maturation factor, Pontuação: 7.262345379577978
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: cysteinyl leukotriene receptor 1, Pontuação: 6.727646810936765
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: myelin oligodendrocyte glycoprotein, Pontuação: 6.706632653061225
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: cathepsin S, Pontuação: 6.617593602326426
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: kinectin 1, Pontuação: 6.586374206593781
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: pannexin 2, Pontuação: 6.470404630458903
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: N-acetyltransferase 10, Pontuação: 6.415214529776369
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: cholesteryl ester transfer protein, Pontuação: 6.334377038486628
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: corticotropin releasing hormone receptor 1, Pontuação: 6.303320508076807
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: dopamine receptor D1, Pontuação: 6.265151515151516
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: apolipoprotein A1, Pontuação: 6.187327343659931
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: vimentin, Pontuação: 6.034285714285715
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: apolipoprotein B, Pontuação: 5.954314974473293
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: lipoprotein(a), Pontuação: 5.9523809523809526
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: adenosine deaminase, Pontuação: 5.914285714285715
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: adenylosuccinate lyase, Pontuação: 5.914285714285715
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: cystathionine beta-synthase, Pontuação: 5.834922371574451
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: MORC family CW-type zinc finger 1, Pontuação: 5.7542857142857144
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: aminoacylase 1, Pontuação: 5.583569879087069
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: cell division cycle 42, Pontuação: 5.571428571428571
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: lipopolysaccharide binding protein, Pontuação: 5.571428571428571
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: parathyroid hormone, Pontuação: 5.519889917438078
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: catechol-O-methyltransferase, Pontuação: 5.421348578955539
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: myelin basic protein, Pontuação: 5.381664914728811
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: synapsin I, Pontuação: 5.376701122927047
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: agmatinase, Pontuação: 5.333190189903617
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: lysozyme, Pontuação: 5.330269459629433
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: mitogen-activated protein kinase 3, Pontuação: 5.32714620002656
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: N-acylethanolamine acid amidase, Pontuação: 5.29136406946011
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: aggrecan, Pontuação: 5.28996138996139
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: neurocan, Pontuação: 5.28996138996139
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: low density lipoprotein receptor, Pontuação: 5.2857142857142865
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: agrin, Pontuação: 5.252747252747253
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: multiple sclerosis, Pontuação: 5.196879820189008
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: thioredoxin, Pontuação: 5.128723526501757
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: nuclear receptor subfamily 4 group A member 1, Pontuação: 3.2185238300230177
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: microtubule associated serine/threonine kinase 3, Pontuação: 2.9956681325870926
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: ST8 alpha-N-acetyl-neuraminide alpha-2,8-sialyltransferase 2, Pontuação: 2.992857142857143
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: retinoic acid receptor alpha, Pontuação: 2.891607406400306
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: prosaposin, Pontuação: 2.558081051289285
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: superoxide dismutase 2, Pontuação: 2.167619047619048
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: arginine vasopressin, Pontuação: 2.129642223069616
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: methylenetetrahydrofolate reductase, Pontuação: 1
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: phosphatidylserine synthase 1, Pontuação: 1
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: telomerase reverse transcriptase, Pontuação: 1
# ID do Autor: 4817, Nome do Autor: Liu S/Autism spectrum disorder, Gene: complement C9, Pontuação: 1

# %% [markdown]
# Disease-Based Split

# %%
import pandas as pd
from surprise import Dataset, Reader, KNNWithMeans
from surprise.model_selection import train_test_split
from surprise import accuracy
from sklearn.metrics import precision_score, recall_score, f1_score
from surprise.model_selection import GridSearchCV


# Carregar os dados do dataset
# Certifique-se de substituir 'all_articles_files_names_merge.csv' pelo caminho correto do seu arquivo CSV
data = pd.read_csv('all_articles_files_names_merge_final4.csv', sep=',')

# Definir o leitor
reader = Reader(rating_scale=(1, data['n_articles'].max()))

# Converter o DataFrame para o formato esperado pelo Surprise
dataset = Dataset.load_from_df(data[['id', 'gene', 'n_articles']], reader=reader)

# Filtrar os exemplos onde a doença é "Autistic disorder" para o conjunto de teste
test_data = data[data['author/disease'].str.contains('Autistic disorder')]

# Filtrar os exemplos onde a doença não é "Autistic disorder" para o conjunto de treino
train_data = data[~data['author/disease'].str.contains('Autistic disorder')]

# Converter os dados de treino e teste para os conjuntos apropriados do Surprise
trainset = dataset.build_full_trainset()
testset = [(row['id'], row['gene'], row['n_articles']) for index, row in test_data.iterrows()]


# Definir o espaço de parâmetros para o GridSearch
param_grid = {'k': [10, 20, 30]}

# Realizar a busca em grid com cross-validation
grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
grid_search.fit(dataset)

# Acessar os melhores parâmetros encontrados
best_params = grid_search.best_params['rmse']

# Treinar o modelo com o conjunto de treino usando os melhores parâmetros
model = KNNWithMeans(k=best_params['k'])
model.fit(trainset)

# Fazer previsões no conjunto de teste
predictions = model.test(testset)

# Calcular as métricas de avaliação
accuracy.rmse(predictions)
accuracy.mae(predictions)

# Obter as classificações previstas e reais
predicted_ratings = [pred.est for pred in predictions]
true_ratings = [pred.r_ui for pred in predictions]

# Converter as classificações em rótulos binários com base no limiar
threshold = 3.5
predicted_labels = [1 if rating >= threshold else 0 for rating in predicted_ratings]
true_labels = [1 if rating >= threshold else 0 for rating in true_ratings]

# Calcular as métricas de precisão, recall e F1-score
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Autor alvo para recomendação
autor_id = 4817

# Obter todos os genes mencionados pelo autor alvo
genes_autor_alvo = data[data['id'] == autor_id]['gene'].unique()

# Realizar as previsões para os genes não mencionados pelo autor alvo
genes_nao_mencionados = data[~data['gene'].isin(genes_autor_alvo)]['gene'].unique()

previsoes = []

for gene in genes_nao_mencionados:
    predicao = model.predict(autor_id, gene)
    previsoes.append((autor_id, gene, predicao.est))

# Ordenar as previsões em ordem decrescente
previsoes_ordenadas = sorted(previsoes, key=lambda x: x[2], reverse=True)

# Obter o nome do autor
autor_nome = data[data['id'] == autor_id]['author/disease'].iloc[0]

# Exibir as melhores previsões
for autor, gene, pontuacao in previsoes_ordenadas:
    print(f'ID do Autor: {autor}, Nome do Autor: {autor_nome}, Gene: {gene}, Pontuação: {pontuacao}')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0